# %%
sales_record = {'price':3.24,'num_items':4,'Person':'Chris'}

# %%
sales_statement  = '{} bought {} items at  a price of {} each fro a total of{}'

# %%
print(sales_statement.format(sales_record['Person'],sales_record['num_items'],sales_record['price'],sales_record['num_items']*sales_record['price']))
# Out:
# Chris bought 4 items at  a price of 3.24 each fro a total of12.96

# %%
import pandas as pd

# %%
pd.Serires?
# Out:
# Object `pd.Serires` not found.

# %%
pd.Series?

# %%
animals = ['Tiger','Bear','Moose']

# %%
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2    Moose
# dtype: object

# %%
numbers = [1,2,3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
animals  = ['Tiger','Bear',None]
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2     None
# dtype: object

# %%
numbers=[1,2,None]
pd.Series(numbers)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
import numpy as np

# %%
np.nan == np.nan
# Out:
# False

# %%
np.isnan(np.nan)
# Out:
# True

# %%
sports = {'Archery':'Bhutan',
          'GOlf':'Scotland',
          'Sumo':'Japan',
          'Taekwondo':'South Korea'}

# %%
sports
# Out:
# {'Archery': 'Bhutan',
#  'GOlf': 'Scotland',
#  'Sumo': 'Japan',
#  'Taekwondo': 'South Korea'}

# %%
 s= pd.Series(sports)

# %%
s
# Out:
# Archery           Bhutan
# GOlf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
s.index.values
# Out:
# array(['Archery', 'GOlf', 'Sumo', 'Taekwondo'], dtype=object)

# %%
s.values
# Out:
# array(['Bhutan', 'Scotland', 'Japan', 'South Korea'], dtype=object)

# %%
s= pd.Series(['Tiger','Bear','Moose'],index = ['A','B','C'])

# %%
s
# Out:
# A    Tiger
# B     Bear
# C    Moose
# dtype: object

# %%
s = pd.Series(sports)

# %%
s
# Out:
# Archery           Bhutan
# GOlf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
#s.loc[3]

# %%
s.iloc[3]
# Out:
# 'South Korea'

# %%
sports = {99:'Bhutan',
         100:'Scotland',
         101:'Japan',
         102:'South korea'}

# %%
s= pd.Series(sports)

# %%
s
# Out:
# 99          Bhutan
# 100       Scotland
# 101          Japan
# 102    South korea
# dtype: object

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-c9c96910e542> in <module>
# ----> 1 s[0]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
s = pd.Series([100.00,120.00,101.00,3.00])

# %%
s

# %%
# %%timeit -n 10
total = 0
for item in s:
    total+=item
print(total)

# %%
import numpy as np

# %%
# %%timeit -n 10
total = np.sum(s)
print(total)

# %%
purchase_1 = pd .Series({'Name':'chris',
                        'Itempurchase':'Dog Food',
                        'Cost':22.50})

# %%
purchase_2 = pd .Series({'Name':'kevyn',
                        'Itempurchase':'kitty litter',
                        'Cost':2.50})

# %%
purchase_3 = pd .Series({'Name':'vinod',
                        'Itempurchase':'bird seed',
                        'Cost':5.00})

# %%
df = pd.DataFrame([purchase_1,purchase_2,purchase_3], index = ['store1','store1','store2'])

# %%
df
# Out:
#          Name  Itempurchase  Cost
# store1  chris      Dog Food  22.5
# store1  kevyn  kitty litter   2.5
# store2  vinod     bird seed   5.0

# %%
df.loc['store1']
# Out:
#          Name  Itempurchase  Cost
# store1  chris      Dog Food  22.5
# store1  kevyn  kitty litter   2.5

# %%
df.iloc[1]
# Out:
# Name                   kevyn
# Itempurchase    kitty litter
# Cost                     2.5
# Name: store1, dtype: object

# %%
type(df['Itempurchase'])
# Out:
# pandas.core.series.Series

# %%
df.loc['store1','Cost']
# Out:
# store1    22.5
# store1     2.5
# Name: Cost, dtype: float64

# %%
df['Cost']
# Out:
# store1    22.5
# store1     2.5
# store2     5.0
# Name: Cost, dtype: float64

# %%
df.T.loc['Cost']
# Out:
# store1    22.5
# store1     2.5
# store2       5
# Name: Cost, dtype: object

# %%
df.loc[:,['Name','Cost']]
# Out:
#          Name  Cost
# store1  chris  22.5
# store1  kevyn   2.5
# store2  vinod   5.0

# %%
df.loc['store1']['Cost']
# Out:
# store1    22.5
# store1     2.5
# Name: Cost, dtype: float64

# %%
copy_df = df.copy()

# %%
copy_df.drop('store1',inplace=True)

# %%
copy_df
# Out:
#          Name Itempurchase  Cost
# store2  vinod    bird seed   5.0

# %%
del copy_df['Name']

# %%
copy_df
# Out:
#        Itempurchase  Cost
# store2    bird seed   5.0

# %%
copy_df.drop('Cost',axis =1)
# Out:
#        Itempurchase
# store2    bird seed

# %%
df
# Out:
#          Name  Itempurchase  Cost
# store1  chris      Dog Food  22.5
# store1  kevyn  kitty litter   2.5
# store2  vinod     bird seed   5.0

# %%
df['location'] =None

# %%
df
# Out:
#          Name  Itempurchase  Cost location
# store1  chris      Dog Food  22.5     None
# store1  kevyn  kitty litter   2.5     None
# store2  vinod     bird seed   5.0     None

# %%
df['Cost']*=0.8

# %%
df
# Out:
#          Name  Itempurchase  Cost location
# store1  chris      Dog Food  18.0     None
# store1  kevyn  kitty litter   2.0     None
# store2  vinod     bird seed   4.0     None

# %%
costs = df['Cost']

# %%
costs += 2

# %%
df
# Out:
#          Name  Itempurchase  Cost location
# store1  chris      Dog Food  20.0     None
# store1  kevyn  kitty litter   4.0     None
# store2  vinod     bird seed   6.0     None

# %%
df =pd.read_csv('/root/Downloads/olympics.csv')

# %%
df
# Out:
#                                                 0         1     2     3     4  \
# 0                                             NaN  № Summer  01 !  02 !  03 !
# 1                               Afghanistan (AFG)        13     0     0     2
# 2                                   Algeria (ALG)        12     5     2     8
# 3                                 Argentina (ARG)        23    18    24    28
# 4                                   Armenia (ARM)         5     1     2     9
# ..                                            ...       ...   ...   ...   ...
# 143  Independent Olympic Participants (IOP) [IOP]         1     0     1     2
# 144                            Zambia (ZAM) [ZAM]        12     0     1     1
# 145                          Zimbabwe (ZIM) [ZIM]        12     3     4     1
# 146                        Mixed team (ZZX) [ZZX]         3     8     5     4
# 147                                        Totals        27  4809  4775  5130
#
# ...

# %%
df = pd.read_csv('/root/Downloads/olympics.csv' , index_col=0,skiprows =1)

# %%
df
# Out:
#                                               № Summer  01 !  02 !  03 !  \
# Afghanistan (AFG)                                   13     0     0     2
# Algeria (ALG)                                       12     5     2     8
# Argentina (ARG)                                     23    18    24    28
# Armenia (ARM)                                        5     1     2     9
# Australasia (ANZ) [ANZ]                              2     3     4     5
# ...                                                ...   ...   ...   ...
# Independent Olympic Participants (IOP) [IOP]         1     0     1     2
# Zambia (ZAM) [ZAM]                                  12     0     1     1
# Zimbabwe (ZIM) [ZIM]                                12     3     4     1
# Mixed team (ZZX) [ZZX]                               3     8     5     4
# Totals                                              27  4809  4775  5130
#
#                                               Total  № Winter  01 !.1  02 !.1  \
# ...

# %%
df.columns
# Out:
# Index(['№ Summer', '01 !', '02 !', '03 !', 'Total', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1', 'Total.1', '№ Games', '01 !.2', '02 !.2', '03 !.2',
#        'Combined total'],
#       dtype='object')

# %%
for col in df.columns:
    if col[:2] == '01':
        df.rename(columns = {col:'Gold'+col[4:]},inplace = True)
    if col[:2] == '02':
        df.rename(columns = {col : 'Silver'+col[4:]},inplace = True)
    if col[:2] == '03':
        df.rename(columns = {col: 'Bronze'+col[4:]},inplace = True)

# %%
df
# Out:
#                                               № Summer  Gold  Silver  Bronze  \
# Afghanistan (AFG)                                   13     0       0       2
# Algeria (ALG)                                       12     5       2       8
# Argentina (ARG)                                     23    18      24      28
# Armenia (ARM)                                        5     1       2       9
# Australasia (ANZ) [ANZ]                              2     3       4       5
# ...                                                ...   ...     ...     ...
# Independent Olympic Participants (IOP) [IOP]         1     0       1       2
# Zambia (ZAM) [ZAM]                                  12     0       1       1
# Zimbabwe (ZIM) [ZIM]                                12     3       4       1
# Mixed team (ZZX) [ZZX]                               3     8       5       4
# Totals                                              27  4809    4775    5130
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Gold']>0
# Out:
# Afghanistan (AFG)                               False
# Algeria (ALG)                                    True
# Argentina (ARG)                                  True
# Armenia (ARM)                                    True
# Australasia (ANZ) [ANZ]                          True
#                                                 ...
# Independent Olympic Participants (IOP) [IOP]    False
# Zambia (ZAM) [ZAM]                              False
# Zimbabwe (ZIM) [ZIM]                             True
# Mixed team (ZZX) [ZZX]                           True
# Totals                                           True
# Name: Gold, Length: 147, dtype: bool

# %%
only_gold = df.where(df['Gold']>0)

# %%
only_gold
# Out:
#                                               № Summer    Gold  Silver  \
# Afghanistan (AFG)                                  NaN     NaN     NaN
# Algeria (ALG)                                     12.0     5.0     2.0
# Argentina (ARG)                                   23.0    18.0    24.0
# Armenia (ARM)                                      5.0     1.0     2.0
# Australasia (ANZ) [ANZ]                            2.0     3.0     4.0
# ...                                                ...     ...     ...
# Independent Olympic Participants (IOP) [IOP]       NaN     NaN     NaN
# Zambia (ZAM) [ZAM]                                 NaN     NaN     NaN
# Zimbabwe (ZIM) [ZIM]                              12.0     3.0     4.0
# Mixed team (ZZX) [ZZX]                             3.0     8.0     5.0
# Totals                                            27.0  4809.0  4775.0
#
#                                               Bronze    Total  № Winter  \
# ...

# %%
only_gold['Gold'].count()
# Out:
# 100

# %%
only_gold.count()
# Out:
# № Summer          100
# Gold              100
# Silver            100
# Bronze            100
# Total             100
# № Winter          100
# Gold.1            100
# Silver.1          100
# Bronze.1          100
# Total.1           100
# № Games           100
# Gold.2            100
# Silver.2          100
# Bronze.2          100
# Combined total    100
# dtype: int64

# %%
only_gold.T.count()
# Out:
# Afghanistan (AFG)                                0
# Algeria (ALG)                                   15
# Argentina (ARG)                                 15
# Armenia (ARM)                                   15
# Australasia (ANZ) [ANZ]                         15
#                                                 ..
# Independent Olympic Participants (IOP) [IOP]     0
# Zambia (ZAM) [ZAM]                               0
# Zimbabwe (ZIM) [ZIM]                            15
# Mixed team (ZZX) [ZZX]                          15
# Totals                                          15
# Length: 147, dtype: int64

# %%
df['Gold'].count()
# Out:
# 147

# %%
only_gold = only_gold.dropna()

# %%
only_gold
# Out:
#                            № Summer    Gold  Silver  Bronze    Total  \
# Algeria (ALG)                  12.0     5.0     2.0     8.0     15.0
# Argentina (ARG)                23.0    18.0    24.0    28.0     70.0
# Armenia (ARM)                   5.0     1.0     2.0     9.0     12.0
# Australasia (ANZ) [ANZ]         2.0     3.0     4.0     5.0     12.0
# Australia (AUS) [AUS] [Z]      25.0   139.0   152.0   177.0    468.0
# ...                             ...     ...     ...     ...      ...
# Venezuela (VEN)                17.0     2.0     2.0     8.0     12.0
# Yugoslavia (YUG) [YUG]         16.0    26.0    29.0    28.0     83.0
# Zimbabwe (ZIM) [ZIM]           12.0     3.0     4.0     1.0      8.0
# Mixed team (ZZX) [ZZX]          3.0     8.0     5.0     4.0     17.0
# Totals                         27.0  4809.0  4775.0  5130.0  14714.0
#
#                            № Winter  Gold.1  Silver.1  Bronze.1  Total.1  \
# ...

# %%
only_gold = df[df['Gold']>0]

# %%
len(df[(df['Gold']>0)|(df['Gold.1']>0)])
# Out:
# 101

# %%
df
# Out:
#                                               № Summer  Gold  Silver  Bronze  \
# Afghanistan (AFG)                                   13     0       0       2
# Algeria (ALG)                                       12     5       2       8
# Argentina (ARG)                                     23    18      24      28
# Armenia (ARM)                                        5     1       2       9
# Australasia (ANZ) [ANZ]                              2     3       4       5
# ...                                                ...   ...     ...     ...
# Independent Olympic Participants (IOP) [IOP]         1     0       1       2
# Zambia (ZAM) [ZAM]                                  12     0       1       1
# Zimbabwe (ZIM) [ZIM]                                12     3       4       1
# Mixed team (ZZX) [ZZX]                               3     8       5       4
# Totals                                              27  4809    4775    5130
#
# ...

# %%
df['country'] = df.index

# %%
df = df.set_index('Gold')

# %%
df
# Out:
#       № Summer  Silver  Bronze  Total  № Winter  Gold.1  Silver.1  Bronze.1  \
# Gold
# 0           13       0       2      2         0       0         0         0
# 5           12       2       8     15         3       0         0         0
# 18          23      24      28     70        18       0         0         0
# 1            5       2       9     12         6       0         0         0
# 3            2       4       5     12         0       0         0         0
# ...        ...     ...     ...    ...       ...     ...       ...       ...
# 0            1       1       2      3         0       0         0         0
# 0           12       1       1      2         0       0         0         0
# 3           12       4       1      8         1       0         0         0
# 8            3       5       4     17         0       0         0         0
# 4809        27    4775    5130  14714        22     959       958       948
#
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#      Gold  № Summer  Silver  Bronze  Total  № Winter  Gold.1  Silver.1  \
# 0       0        13       0       2      2         0       0         0
# 1       5        12       2       8     15         3       0         0
# 2      18        23      24      28     70        18       0         0
# 3       1         5       2       9     12         6       0         0
# 4       3         2       4       5     12         0       0         0
# ..    ...       ...     ...     ...    ...       ...     ...       ...
# 142     0         1       1       2      3         0       0         0
# 143     0        12       1       1      2         0       0         0
# 144     3        12       4       1      8         1       0         0
# 145     8         3       5       4     17         0       0         0
# 146  4809        27    4775    5130  14714        22     959       958
#
#      Bronze.1  Total.1  № Games  Gold.2  Silver.2  Bronze.2  Combined total  \
# ...

# %%
df = pd.read_csv('/root/Downloads/census.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
df['SUMLEV'].unique()
# Out:
# array([40, 50])

# %%
df = df[df['SUMLEV']==50]

# %%
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# 5         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
df.set_index(['STNAME','CTYNAME'])
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# 5         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
df.set_index(['STNAME','CTYNAME'])
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County         50       3         6      1       1
#         Baldwin County         50       3         6      1       3
#         Barbour County         50       3         6      1       5
#         Bibb County            50       3         6      1       7
#         Blount County          50       3         6      1       9
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County      50       4         8     56      37
#         Teton County           50       4         8     56      39
#         Uinta County           50       4         8     56      41
#         Washakie County        50       4         8     56      43
#         Weston County          50       4         8     56      45
#
#                            CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# ...

# %%
df.loc['Michigan','Washtenaw County']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Michigan'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-8db9a9663f64> in <module>
# ----> 1 df.loc['Michigan','Washtenaw County']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
# ...

# %%
purchase_1
# Out:
# Name               chris
# Itempurchase    Dog Food
# Cost                22.5
# dtype: object

# %%
df = pd.DataFrame([purchase_1,purchase_2,purchase_3],index = ('store1','store1','store2'))

# %%
df
# Out:
#          Name  Itempurchase  Cost
# store1  chris      Dog Food  22.5
# store1  kevyn  kitty litter   2.5
# store2  vinod     bird seed   5.0

# %%
df= df.set_index([df.index,'Name'])

# %%
df.index_names = ['Location','Name']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#               Itempurchase  Cost
#        Name
# store1 chris      Dog Food  22.5
#        kevyn  kitty litter   2.5
# store2 vinod     bird seed   5.0

# %%
df = df.append(pd.Series(data = {'Cost':3.00,'Itempurchase':'Kitty Food'},name = ('store2','Kevyn')))

# %%
df
# Out:
#               Itempurchase  Cost
#        Name
# store1 chris      Dog Food  22.5
#        kevyn  kitty litter   2.5
# store2 vinod     bird seed   5.0
#        Kevyn    Kitty Food   3.0

# %%
df = pd.read_csv('/root/Downloads/log.csv')

# %%
df
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     NaN
# 2   1469974544  cheryl     intro.html                  9    NaN     NaN
# 3   1469974574  cheryl     intro.html                 10    NaN     NaN
# 4   1469977514     bob     intro.html                  1    NaN     NaN
# 5   1469977544     bob     intro.html                  1    NaN     NaN
# 6   1469977574     bob     intro.html                  1    NaN     NaN
# 7   1469977604     bob     intro.html                  1    NaN     NaN
# 8   1469974604  cheryl     intro.html                 11    NaN     NaN
# 9   1469974694  cheryl     intro.html                 14    NaN     NaN
# 10  1469974724  cheryl     intro.html                 15    NaN     NaN
# 11  1469974454     sue  advanced.html                 24    NaN     NaN
# ...

# %%
df = df.set_index('time')

# %%
df
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974544  cheryl     intro.html                  9    NaN     NaN
# 1469974574  cheryl     intro.html                 10    NaN     NaN
# 1469977514     bob     intro.html                  1    NaN     NaN
# 1469977544     bob     intro.html                  1    NaN     NaN
# 1469977574     bob     intro.html                  1    NaN     NaN
# 1469977604     bob     intro.html                  1    NaN     NaN
# 1469974604  cheryl     intro.html                 11    NaN     NaN
# 1469974694  cheryl     intro.html                 14    NaN     NaN
# 1469974724  cheryl     intro.html                 15    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974524     sue  advanced.html                 25    NaN     NaN
# ...

# %%
df = df.sort_index()

# %%
df
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974424     sue  advanced.html                 23  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974484  cheryl     intro.html                  7    NaN     NaN
# 1469974514  cheryl     intro.html                  8    NaN     NaN
# 1469974524     sue  advanced.html                 25    NaN     NaN
# 1469974544  cheryl     intro.html                  9    NaN     NaN
# 1469974554     sue  advanced.html                 26    NaN     NaN
# 1469974574  cheryl     intro.html                 10    NaN     NaN
# 1469974604  cheryl     intro.html                 11    NaN     NaN
# 1469974624     sue  advanced.html                 27    NaN     NaN
# 1469974634  cheryl     intro.html                 12    NaN     NaN
# ...

# %%
df =df.reset_index()

# %%
df = df.set_index(['time','user'])

# %%
df
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
#            sue     advanced.html                 24    NaN     NaN
# 1469974484 cheryl     intro.html                  7    NaN     NaN
# 1469974514 cheryl     intro.html                  8    NaN     NaN
# 1469974524 sue     advanced.html                 25    NaN     NaN
# 1469974544 cheryl     intro.html                  9    NaN     NaN
# 1469974554 sue     advanced.html                 26    NaN     NaN
# 1469974574 cheryl     intro.html                 10    NaN     NaN
# 1469974604 cheryl     intro.html                 11    NaN     NaN
# 1469974624 sue     advanced.html                 27    NaN     NaN
# 1469974634 cheryl     intro.html                 12    NaN     NaN
# ...

# %%
df.fillna
# Out:
# <bound method DataFrame.fillna of                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
#            sue     advanced.html                 24    NaN     NaN
# 1469974484 cheryl     intro.html                  7    NaN     NaN
# 1469974514 cheryl     intro.html                  8    NaN     NaN
# 1469974524 sue     advanced.html                 25    NaN     NaN
# 1469974544 cheryl     intro.html                  9    NaN     NaN
# 1469974554 sue     advanced.html                 26    NaN     NaN
# 1469974574 cheryl     intro.html                 10    NaN     NaN
# 1469974604 cheryl     intro.html                 11    NaN     NaN
# 1469974624 sue     advanced.html                 27    NaN     NaN
# ...

# %%
df
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
#            sue     advanced.html                 24    NaN     NaN
# 1469974484 cheryl     intro.html                  7    NaN     NaN
# 1469974514 cheryl     intro.html                  8    NaN     NaN
# 1469974524 sue     advanced.html                 25    NaN     NaN
# 1469974544 cheryl     intro.html                  9    NaN     NaN
# 1469974554 sue     advanced.html                 26    NaN     NaN
# 1469974574 cheryl     intro.html                 10    NaN     NaN
# 1469974604 cheryl     intro.html                 11    NaN     NaN
# 1469974624 sue     advanced.html                 27    NaN     NaN
# 1469974634 cheryl     intro.html                 12    NaN     NaN
# ...

# %%
df.fillna(0)
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6      0     0.0
#            sue     advanced.html                 24      0     0.0
# 1469974484 cheryl     intro.html                  7      0     0.0
# 1469974514 cheryl     intro.html                  8      0     0.0
# 1469974524 sue     advanced.html                 25      0     0.0
# 1469974544 cheryl     intro.html                  9      0     0.0
# 1469974554 sue     advanced.html                 26      0     0.0
# 1469974574 cheryl     intro.html                 10      0     0.0
# 1469974604 cheryl     intro.html                 11      0     0.0
# 1469974624 sue     advanced.html                 27      0     0.0
# 1469974634 cheryl     intro.html                 12      0     0.0
# ...

# %%
diction  = {'A':10,'B':20,'C':30}

# %%
ser = pd.Series(diction,dtype = int)

# %%
s

# %%
s+=2
s.head()

# %%
for label,value in s.iteritems():
    s.set_value(label,value+2)
s.head()

# %%
.at?

# %%
.at

# %%
# %%timeit -n 10
s=pd.Series(np.random.randint(0,1000,10000))
for label ,value in s.iteritems():
    s.loc[label] = value+2

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
s+=2

# %%
import pandas as pd

# %%
s = pd.Series([1,2,3])

# %%
s.loc['Animal'] = 'Bears'

# %%
s

# %%
sports = {'Archery':'Bhutan',
          'GOlf':'Scotland',
          'Sumo':'Japan',
          'Taekwondo':'South Korea'}

# %%
original_sport = pd.Series(sports)

# %%
cricket_loving = pd.Series(['Australia','Barbados','pakistan','England'],index = ['cricket','cricket','cricket','cricket'])

# %%
cricket_loving_count = pd.Series(cricket_loving)

# %%
all_countries = original_sport.append(cricket_loving_count)

# %%
all_countries

# %%
all_countries.columns()

# %%
s1= pd.Series(['Dog','Bear','Tiger','Moose','Giraffe','Hippo','Mouse'])
s2= pd.Series(['Chris','Kevyn','Bob','Vinod','Daniel','Fil','Stephanie'])

# %%
df = pd.DataFrame({"Animals":['Dog','Bear','Tiger','Moose','Giraffe','Hippo','Mouse'],
                 "owners":['Chris','Kevyn','Bob','Vinod','Daniel','Fil','Stephanie']})

# %%
df

# %%
df.index.values

# %%
df.iloc[0]['Animals']

# %%
purchase_1 = pd.Series({'Name':['babu','Chris']})

# %%
df.argmax

# %%
df.values

# %%
df

# %%
type(diction)

# %%
import pandas as pd

# %%
df = pd.read_csv('/root/Downloads/census.csv')

# %%
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
df = df[df['SUMLEV']==50]

# %%
import numpy as np

# %%
for state in df['STNAME'].unique():
    avg = np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])
    print('counties in state' + state +'have an average population of'+ str(avg))
# Out:
# counties in stateAlabamahave an average population of71339.34328358209
# counties in stateAlaskahave an average population of24490.724137931036
# counties in stateArizonahave an average population of426134.4666666667
# counties in stateArkansashave an average population of38878.90666666667
# counties in stateCaliforniahave an average population of642309.5862068966
# counties in stateColoradohave an average population of78581.1875
# counties in stateConnecticuthave an average population of446762.125
# counties in stateDelawarehave an average population of299311.3333333333
# counties in stateDistrict of Columbiahave an average population of601723.0
# counties in stateFloridahave an average population of280616.5671641791
# counties in stateGeorgiahave an average population of60928.63522012578
# counties in stateHawaiihave an average population of272060.2
# counties in stateIdahohave an average population of35626.86363636364
# ...

# %%
for group ,frame in df.groupby('STNAME'):
    avg = np.average(frame['CENSUS2010POP'])
    print('Counties in state' +  group + 'have an average popln of'+ str(avg))
# Out:
# Counties in stateAlabamahave an average popln of71339.34328358209
# Counties in stateAlaskahave an average popln of24490.724137931036
# Counties in stateArizonahave an average popln of426134.4666666667
# Counties in stateArkansashave an average popln of38878.90666666667
# Counties in stateCaliforniahave an average popln of642309.5862068966
# Counties in stateColoradohave an average popln of78581.1875
# Counties in stateConnecticuthave an average popln of446762.125
# Counties in stateDelawarehave an average popln of299311.3333333333
# Counties in stateDistrict of Columbiahave an average popln of601723.0
# Counties in stateFloridahave an average popln of280616.5671641791
# Counties in stateGeorgiahave an average popln of60928.63522012578
# Counties in stateHawaiihave an average popln of272060.2
# Counties in stateIdahohave an average popln of35626.86363636364
# Counties in stateIllinoishave an average popln of125790.50980392157
# ...

# %%
def fun(item):
    if item[0]<'M':
        return 0
    if item[0]<'Q':
        return 1
    return 2

# %%
df = df.set_index('STNAME')

# %%
for group,frame in df.groupby(fun):
    print('There are' + str(len(frame)) + 'records in group' + str(group) + 'for processing')
# Out:
# There are1177records in group0for processing
# There are1134records in group1for processing
# There are831records in group2for processing

# %%
df = pd.read_csv('/root/Downloads/census.csv')
df = df[df['SUMLEV']==50]

# %%
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# 5         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
df.groupby('STNAME').agg({'CENSUS2010POP':np.average})
# Out:
#                       CENSUS2010POP
# STNAME
# Alabama                71339.343284
# Alaska                 24490.724138
# Arizona               426134.466667
# Arkansas               38878.906667
# California            642309.586207
# Colorado               78581.187500
# Connecticut           446762.125000
# Delaware              299311.333333
# District of Columbia  601723.000000
# Florida               280616.567164
# Georgia                60928.635220
# Hawaii                272060.200000
# Idaho                  35626.863636
# Illinois              125790.509804
# Indiana                70476.108696
# Iowa                   30771.262626
# Kansas                 27172.552381
# Kentucky               36161.391667
# Louisiana              70833.937500
# Maine                  83022.562500
# Maryland              240564.666667
# Massachusetts         467687.785714
# Michigan              119080.000000
# Minnesota              60964.655172
# Mississippi            36186.548780
# ...

# %%
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# 5         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
print(type(df.groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
print(type(df.groupby(level=0)['POPESTIMATE2010']))
# Out:
# <class 'pandas.core.groupby.generic.SeriesGroupBy'>

# %%
df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg({'avg':np.average,'sum':np.sum})
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   """Entry point for launching an IPython kernel.
#                                 avg       sum
# STNAME
# Alabama                71339.343284   4779736
# Alaska                 24490.724138    710231
# Arizona               426134.466667   6392017
# Arkansas               38878.906667   2915918
# California            642309.586207  37253956
# Colorado               78581.187500   5029196
# Connecticut           446762.125000   3574097
# Delaware              299311.333333    897934
# District of Columbia  601723.000000    601723
# Florida               280616.567164  18801310
# Georgia                60928.635220   9687653
# Hawaii                272060.200000   1360301
# ...

# %%
df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011'].agg({'avg':np.average,'sum':np.sum})
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py:1455: FutureWarning: using a dict with renaming is deprecated and will be removed
# in a future version.
#
# For column-specific groupby renaming, use named aggregation
#
#     >>> df.groupby(...).agg(name=('column', aggfunc))
#
#   return super().aggregate(arg, *args, **kwargs)
#                                  avg                             sum  \
#                      POPESTIMATE2010 POPESTIMATE2011 POPESTIMATE2010
# STNAME
# Alabama                 71420.313433    71658.328358         4785161
# Alaska                  24621.413793    24921.379310          714021
# Arizona                427213.866667   431248.800000         6408208
# Arkansas                38965.253333    39180.506667         2922394
# California             643691.017241   650000.586207        37334079
# Colorado                78878.968750    79991.875000         5048254
# ...

# %%
df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011'].agg({'POPESTIMATE2010':np.average,'POPESTIMATE2011':np.sum})
# Out:
#                       POPESTIMATE2010  POPESTIMATE2011
# STNAME
# Alabama                  71420.313433          4801108
# Alaska                   24621.413793           722720
# Arizona                 427213.866667          6468732
# Arkansas                 38965.253333          2938538
# California              643691.017241         37700034
# Colorado                 78878.968750          5119480
# Connecticut             447464.625000          3589759
# Delaware                299930.333333           907916
# District of Columbia    605126.000000           620472
# Florida                 281341.641791         19105533
# Georgia                  61090.905660          9812280
# Hawaii                  272796.000000          1378227
# Idaho                    35704.227273          1584134
# Illinois                125894.598039         12861882
# Indiana                  70549.891304          6516845
# Iowa                     30815.090909          3065389
# ...

# %%
df = pd.DataFrame(['A+','A','A-','B+','B','B-','C+','C','C-','D+','D'],index=['excellent','excellent','excellent','good','good','good','ok','ok','ok','poor','poor'])

# %%
df.rename(columns={0:'Grades'},inplace=True)

# %%
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
df['Grades'].astype('category')
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
from pandas.api.types import CategoricalDtype

# %%
grades = df['Grades'].astype('category',CategoricalDtype(categories=['A+','A','A-','B+','B','B-','C+','C','C-','D+','D'],ordered=True))

# %%
grades
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
grades>'C'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-2c8a210c736d> in <module>
# ----> 1 grades>'C'
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1145             # Dispatch to Categorical implementation; pd.CategoricalIndex
#    1146             # behavior is non-canonical GH#19513
# -> 1147             res_values = dispatch_to_index_op(op, self, other, pd.Categorical)
#    1148             return self._constructor(res_values, index=self.index, name=res_name)
#    1149
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/__init__.py in dispatch_to_index_op(op, left, right, index_class)
#     628         left_idx = left_idx._shallow_copy(freq=None)
#     629     try:
# --> 630         result = op(left_idx, right)
#     631     except NullFrequencyError:
# ...

# %%
s= CategoricalDtype(categories=['A+','A','A-','B+','B','B-','C+','C','C-','D+','D'],ordered=True)

# %%
s
# Out:
# CategoricalDtype(categories=['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+',
#                   'D'],
#                  ordered=True)

# %%
df = pd.read_csv('/root/Downloads/census.csv')

# %%
df = df[df['SUMLEV']==50]

# %%
df = df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg({'avg':np.average})
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                                 avg
# STNAME
# Alabama                71339.343284
# Alaska                 24490.724138
# Arizona               426134.466667
# Arkansas               38878.906667
# California            642309.586207
# Colorado               78581.187500
# Connecticut           446762.125000
# Delaware              299311.333333
# District of Columbia  601723.000000
# Florida               280616.567164
# Georgia                60928.635220
# Hawaii                272060.200000
# Idaho                  35626.863636
# Illinois              125790.509804
# Indiana                70476.108696
# Iowa                   30771.262626
# Kansas                 27172.552381
# Kentucky               36161.391667
# Louisiana              70833.937500
# Maine                  83022.562500
# Maryland              240564.666667
# Massachusetts         467687.785714
# Michigan              119080.000000
# Minnesota              60964.655172
# Mississippi            36186.548780
# ...

# %%
pd.cut(df['avg'],10)
# Out:
# STNAME
# Alabama                   (11706.087, 75333.413]
# Alaska                    (11706.087, 75333.413]
# Arizona                 (390320.176, 453317.529]
# Arkansas                  (11706.087, 75333.413]
# California              (579312.234, 642309.586]
# Colorado                 (75333.413, 138330.766]
# Connecticut             (390320.176, 453317.529]
# Delaware                (264325.471, 327322.823]
# District of Columbia    (579312.234, 642309.586]
# Florida                 (264325.471, 327322.823]
# Georgia                   (11706.087, 75333.413]
# Hawaii                  (264325.471, 327322.823]
# Idaho                     (11706.087, 75333.413]
# Illinois                 (75333.413, 138330.766]
# Indiana                   (11706.087, 75333.413]
# Iowa                      (11706.087, 75333.413]
# Kansas                    (11706.087, 75333.413]
# Kentucky                  (11706.087, 75333.413]
# Louisiana                 (11706.087, 75333.413]
# ...

# %%
s= pd.Series([168,180,174,190,170,185,179,181,175,169,182,177,180,171])

# %%
pd.cut(s,3,labels=['Small','Medium','Large'])
# Out:
# 0      Small
# 1     Medium
# 2      Small
# 3      Large
# 4      Small
# 5      Large
# 6     Medium
# 7     Medium
# 8      Small
# 9      Small
# 10    Medium
# 11    Medium
# 12    Medium
# 13     Small
# dtype: category
# Categories (3, object): [Small < Medium < Large]

# %%
df = pd.read_csv('/root/Downloads/cars.csv')

# %%
df
# Out:
#     YEAR        Make                            Model                   Size  \
# 0   2012  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 1   2012      NISSAN                             LEAF               MID-SIZE
# 2   2013        FORD                   FOCUS ELECTRIC                COMPACT
# 3   2013  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 4   2013      NISSAN                             LEAF               MID-SIZE
# 5   2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 6   2013       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 7   2013       TESLA         MODEL S (40 kWh battery)              FULL-SIZE
# 8   2013       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 9   2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 10  2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# ...

# %%
df.pivot_table(values = '(kW)',index = 'YEAR',columns = 'Make',aggfunc = np.mean)
# Out:
# Make    BMW  CHEVROLET   FORD   KIA  MITSUBISHI  NISSAN  SMART       TESLA
# YEAR
# 2012    NaN        NaN    NaN   NaN        49.0    80.0    NaN         NaN
# 2013    NaN        NaN  107.0   NaN        49.0    80.0   35.0  280.000000
# 2014    NaN      104.0  107.0   NaN        49.0    80.0   35.0  268.333333
# 2015  125.0      104.0  107.0  81.0        49.0    80.0   35.0  320.666667
# 2016  125.0      104.0  107.0  81.0        49.0    80.0   35.0  409.700000

# %%
s = pd.DataFrame([{'Biketype':'mountsin','Manufaturer':'A','Price':400,'Rating':8},
                 {'Biketype':'mountsin','Manufaturer':'A','Price':600,'Rating':9},
                 {'Biketype':'Road','Manufaturer':'A','Price':400,'Rating':4},
                 {'Biketype':'Road','Manufaturer':'A','Price':450,'Rating':4},
                 {'Biketype':'mountsin','Manufaturer':'B','Price':800,'Rating':6},
                 {'Biketype':'mountsin','Manufaturer':'B','Price':400,'Rating':8},
                 {'Biketype':'Road','Manufaturer':'A','Price':300,'Rating':8}])

# %%
print(pd.pivot_table(s,index=['Manufaturer','Biketype'],aggfunc=np.mean))
# Out:
#                            Price    Rating
# Manufaturer Biketype
# A           Road      383.333333  5.333333
#             mountsin  500.000000  8.500000
# B           mountsin  600.000000  7.000000

# %%
pd.Timestamp('9/1/2016 10:05 AM')
# Out:
# Timestamp('2016-09-01 10:05:00')

# %%
pd.Period('1/2016')
# Out:
# Period('2016-01', 'M')

# %%
pd.Period('2016-03-05')
# Out:
# Period('2016-03-05', 'D')

# %%
t1 = pd.Series(list('abc'),[pd.Timestamp('2016-09-01'),
                           pd.Timestamp('2016-09-02'),
                           pd.Timestamp('2016-09-03')])

# %%
t1
# Out:
# 2016-09-01    a
# 2016-09-02    b
# 2016-09-03    c
# dtype: object

# %%
t2 = pd.Series(list('abc'),[pd.Period('2016-09-01'),
                           pd.Period('2016-09-02'),
                           pd.Period('2016-09-03')])

# %%
t2
# Out:
# 2016-09-01    a
# 2016-09-02    b
# 2016-09-03    c
# Freq: D, dtype: object

# %%
type(t2.index)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
d1 = ['2 june 2013','Aug 29 2014','2015-06-26','7/12/16']

# %%
ts3 = pd.DataFrame(np.random.randint(10,100,(4,2)),index=d1,columns = list('ab'))

# %%
ts3
# Out:
#               a   b
# 2 june 2013  21  14
# Aug 29 2014  72  58
# 2015-06-26   90  82
# 7/12/16      68  75

# %%
ts3.index = pd.to_datetime(ts3.index)

# %%
ts3
# Out:
#              a   b
# 2013-06-02  21  14
# 2014-08-29  72  58
# 2015-06-26  90  82
# 2016-07-12  68  75

# %%
pd.to_datetime('4.7.12',dayfirst = True)
# Out:
# Timestamp('2012-07-04 00:00:00')

# %%
dates = pd.date_range('10-01-2016',periods=9,freq='2W-SUN')

# %%
dates
# Out:
# DatetimeIndex(['2016-10-02', '2016-10-16', '2016-10-30', '2016-11-13',
#                '2016-11-27', '2016-12-11', '2016-12-25', '2017-01-08',
#                '2017-01-22'],
#               dtype='datetime64[ns]', freq='2W-SUN')

# %%
df = pd.DataFrame({'count1':100+np.random.randint(-5,10,9).cumsum(),'count2':120+np.random.randint(-5,10,9)},index=dates)

# %%
df
# Out:
#             count1  count2
# 2016-10-02      95     128
# 2016-10-16      93     116
# 2016-10-30      92     126
# 2016-11-13      94     126
# 2016-11-27     100     127
# 2016-12-11     107     116
# 2016-12-25     103     127
# 2017-01-08     109     123
# 2017-01-22     105     123

# %%
df.index.weekday_name
# Out:
# Index(['Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday', 'Sunday',
#        'Sunday', 'Sunday'],
#       dtype='object')

# %%
df.diff()
# Out:
#             count1  count2
# 2016-10-02     NaN     NaN
# 2016-10-16    -2.0   -12.0
# 2016-10-30    -1.0    10.0
# 2016-11-13     2.0     0.0
# 2016-11-27     6.0     1.0
# 2016-12-11     7.0   -11.0
# 2016-12-25    -4.0    11.0
# 2017-01-08     6.0    -4.0
# 2017-01-22    -4.0     0.0

# %%
df.resample('M').mean()
# Out:
#                 count1      count2
# 2016-10-31   93.333333  123.333333
# 2016-11-30   97.000000  126.500000
# 2016-12-31  105.000000  121.500000
# 2017-01-31  107.000000  123.000000

# %%
df['2017']
# Out:
#             count1  count2
# 2017-01-08     109     123
# 2017-01-22     105     123

# %%
df['2016-12']
# Out:
#             count1  count2
# 2016-12-11     107     116
# 2016-12-25     103     127

# %%
df['2016-12':]
# Out:
#             count1  count2
# 2016-12-11     107     116
# 2016-12-25     103     127
# 2017-01-08     109     123
# 2017-01-22     105     123

# %%
df.asfreq('W')
# Out:
#             count1  count2
# 2016-10-02    95.0   128.0
# 2016-10-09     NaN     NaN
# 2016-10-16    93.0   116.0
# 2016-10-23     NaN     NaN
# 2016-10-30    92.0   126.0
# 2016-11-06     NaN     NaN
# 2016-11-13    94.0   126.0
# 2016-11-20     NaN     NaN
# 2016-11-27   100.0   127.0
# 2016-12-04     NaN     NaN
# 2016-12-11   107.0   116.0
# 2016-12-18     NaN     NaN
# 2016-12-25   103.0   127.0
# 2017-01-01     NaN     NaN
# 2017-01-08   109.0   123.0
# 2017-01-15     NaN     NaN
# 2017-01-22   105.0   123.0

# %%
df.asfreq('W',method = 'ffill')
# Out:
#             count1  count2
# 2016-10-02      95     128
# 2016-10-09      95     128
# 2016-10-16      93     116
# 2016-10-23      93     116
# 2016-10-30      92     126
# 2016-11-06      92     126
# 2016-11-13      94     126
# 2016-11-20      94     126
# 2016-11-27     100     127
# 2016-12-04     100     127
# 2016-12-11     107     116
# 2016-12-18     107     116
# 2016-12-25     103     127
# 2017-01-01     103     127
# 2017-01-08     109     123
# 2017-01-15     109     123
# 2017-01-22     105     123

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df.plot()

# %%
np.random.binomial(1,0.5)
# Out:
# 1

# %%
np.random.binomial(1000,0.5)/1000
# Out:
# 0.501

# %%
x = np.random.binomial(20,0.5,10000)

# %%
print((x>=15).mean())
# Out:
# 0.021

# %%
chance_of_tornado = .01

# %%
np.random.binomial(10000,chance_of_tornado)
# Out:
# 105

# %%
tornado_events = np.random.binomial(1,chance_of_tornado,1000000)

# %%
tornado_events[5]
# Out:
# 0

# %%
len(tornado_events)
# Out:
# 1000000

# %%
two_days_in_row = 0
for j in range(1,len(tornado_events)-1):
    if tornado_events[j] == 1 and tornado_events[j-1]==1:
        two_days_in_row+= 1
        
print('{} tornadoes back to back in {} years'.format(two_days_in_row,1000000/36))
# Out:
# 91 tornadoes back to back in 27777.777777777777 years

# %%
np.random.uniform(0,1)
# Out:
# 0.7257864895199273

# %%
np.random.normal(0.75)
# Out:
# 2.509736605294737

# %%
distribution = np.random.normal(0.75,size=1000)

# %%
np.sqrt(np.sum((np.mean(distribution)-distribution)**2)/len(distribution))
# Out:
# 1.0274448550239654

# %%
np.std(distribution)
# Out:
# 1.0274448550239654

# %%
import scipy.stats as stats

# %%
stats.kurtosis(distribution)
# Out:
# 0.2979607106288631

# %%
stats.skew(distribution)
# Out:
# 0.053704683110687275

# %%
chi_squared_df2 = np.random.chisquare(2,size=10000)

# %%
stats.skew(chi_squared_df2)
# Out:
# 1.8769025618526871

# %%
chi_squared_df5 = np.random.chisquare(5,size=10000)

# %%
stats.skew(chi_squared_df5)
# Out:
# 1.2592733611135791

# %%
# %matplotlib inline

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
output = plt.hist([chi_squared_df2,chi_squared_df5],bins=50,histtype='step',label = ['2 degrees of freedom','5 degree of freedom'])
plt.legend(loc = 'upper right')

# %%
df = pd.read_csv('/root/Downloads/grades.csv')

# %%
df.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# ...

# %%
early = df[df['assignment1_submission']<= '2015-12-31']

# %%
late = df[df['assignment1_submission'] > '2015-12-31']

# %%
early.mean()
# Out:
# assignment1_grade    74.972741
# assignment2_grade    67.252190
# assignment3_grade    61.129050
# assignment4_grade    54.157620
# assignment5_grade    48.634643
# assignment6_grade    43.838980
# dtype: float64

# %%
late.mean()
# Out:
# assignment1_grade    74.017429
# assignment2_grade    66.370822
# assignment3_grade    60.023244
# assignment4_grade    54.058138
# assignment5_grade    48.599402
# assignment6_grade    43.844384
# dtype: float64

# %%
stats.ttest_ind(early['assignment1_grade'],late['assignment1_grade'])
# Out:
# Ttest_indResult(statistic=1.400549944897566, pvalue=0.16148283016060577)

# %%
for i in range(6 - 3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
 for i in range(len(df) - 4):
        if ((df.iloc[i][1] > df.iloc[i+1][1]) & (df.iloc[i+1][1] > df.iloc[i+2][1]) & (df.iloc[i+2][1] < df.iloc[i+3][1]) & (df.iloc[i+3][1] < df.iloc[i+4][1])):
            recession_end.append([df.iloc[i][0],df.iloc[i+1][0],df.iloc[i+2][0],df.iloc[i+3][0],df.iloc[i+4][0]])

    ans = recession_end[0][4]

# %%
df = pd.read_excel('/root/Downloads/gdplev.xls',skiprows=7)

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0        1929.0       104.6      1056.6         NaN     1947q1       243.1
# 1        1930.0        92.2       966.7         NaN     1947q2       246.3
# 2        1931.0        77.4       904.8         NaN     1947q3       250.1
# 3        1932.0        59.5       788.2         NaN     1947q4       260.3
# 4        1933.0        57.2       778.3         NaN     1948q1       266.2
# ..          ...         ...         ...         ...        ...         ...
# 273         NaN         NaN         NaN         NaN     2015q2     17998.3
# 274         NaN         NaN         NaN         NaN     2015q3     18141.9
# 275         NaN         NaN         NaN         NaN     2015q4     18222.8
# 276         NaN         NaN         NaN         NaN     2016q1     18281.6
# 277         NaN         NaN         NaN         NaN     2016q2     18450.1
#
#      Unnamed: 6  Unnamed: 7
# 0        1934.5         NaN
# ...

# %%
df = df[['Unnamed: 4','Unnamed: 5']]

# %%
df
# Out:
#     Unnamed: 4  Unnamed: 5
# 0       1947q1       243.1
# 1       1947q2       246.3
# 2       1947q3       250.1
# 3       1947q4       260.3
# 4       1948q1       266.2
# ..         ...         ...
# 273     2015q2     17998.3
# 274     2015q3     18141.9
# 275     2015q4     18222.8
# 276     2016q1     18281.6
# 277     2016q2     18450.1
#
# [278 rows x 2 columns]

# %%
df.columns = ['Quarters','GDP']

# %%
df = df.iloc[212:]

# %%
df =df.reset_index()

# %%
df = df[['Quarters','GDP']]

# %%
df
# Out:
#    Quarters      GDP
# 0    2000q1  10031.0
# 1    2000q2  10278.3
# 2    2000q3  10357.4
# 3    2000q4  10472.3
# 4    2001q1  10508.1
# ..      ...      ...
# 61   2015q2  17998.3
# 62   2015q3  18141.9
# 63   2015q4  18222.8
# 64   2016q1  18281.6
# 65   2016q2  18450.1
#
# [66 rows x 2 columns]

# %%
recession_start = []
for i in range(len(df )- 2):
    for i in range(len(df) - 4):
        if ((df.iloc[i][1] > df.iloc[i+1][1]) & (df.iloc[i+1][1] > df.iloc[i+2][1]) & (df.iloc[i+2][1] < df.iloc[i+3][1]) & (df.iloc[i+3][1] < df.iloc[i+4][1])):
            recession_start.append([df.iloc[i][0],df.iloc[i+1][0],df.iloc[i+2][0],df.iloc[i+3][0],df.iloc[i+4][0]])

    ans = recession_start[0][4]
    
    

ans
# Out:
# '2009q4'

# %%
ans
# Out:
# '2009q4'

# %%
for i in range(len(df) - 4):
        if ((df.iloc[i][1] > df.iloc[i+1][1]) & (df.iloc[i+1][1] > df.iloc[i+2][1]) & (df.iloc[i+2][1] < df.iloc[i+3][1]) & (df.iloc[i+3][1] < df.iloc[i+4][1])):
            recession_end.append([df.iloc[i][0],df.iloc[i+1][0],df.iloc[i+2][0],df.iloc[i+3][0],df.iloc[i+4][0]])

# %%
df = pd.read_csv('/root/Downloads/City_Zhvi_AllHomes.csv')

# %%
df
# Out:
#        RegionID           RegionName State                           Metro  \
# 0          6181             New York    NY                        New York
# 1         12447          Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 2         17426              Chicago    IL                         Chicago
# 3         13271         Philadelphia    PA                    Philadelphia
# 4         40326              Phoenix    AZ                         Phoenix
# ...         ...                  ...   ...                             ...
# 10725    398292  Town of Wrightstown    WI                       Green Bay
# 10726    398343               Urbana    NY                         Corning
# 10727    398496          New Denmark    WI                       Green Bay
# 10728    398839               Angels    CA                             NaN
# 10729    399114              Holland    WI                       Sheboygan
#
# ...

# %%
df = df.drop(df.columns[[0] + list(range(3,51))],axis=1)

# %%
df
# Out:
#                 RegionName State   2000-01   2000-02   2000-03   2000-04  \
# 0                 New York    NY       NaN       NaN       NaN       NaN
# 1              Los Angeles    CA  204400.0  207000.0  209800.0  212300.0
# 2                  Chicago    IL  136800.0  138300.0  140100.0  141900.0
# 3             Philadelphia    PA   52700.0   53100.0   53200.0   53400.0
# 4                  Phoenix    AZ  111000.0  111700.0  112800.0  113700.0
# ...                    ...   ...       ...       ...       ...       ...
# 10725  Town of Wrightstown    WI  101100.0  101500.0  102700.0  103700.0
# 10726               Urbana    NY   77600.0   79400.0   80600.0   80200.0
# 10727          New Denmark    WI  113900.0  114000.0  115800.0  117600.0
# 10728               Angels    CA  148000.0  151200.0  153800.0  155600.0
# 10729              Holland    WI  150800.0  151000.0  151300.0  151000.0
#
#         2000-05   2000-06   2000-07   2000-08  ...  2015-11  2015-12  2016-01  \
# ...

# %%
df
# Out:
#                 RegionName State   2000-01   2000-02   2000-03   2000-04  \
# 0                 New York    NY       NaN       NaN       NaN       NaN
# 1              Los Angeles    CA  204400.0  207000.0  209800.0  212300.0
# 2                  Chicago    IL  136800.0  138300.0  140100.0  141900.0
# 3             Philadelphia    PA   52700.0   53100.0   53200.0   53400.0
# 4                  Phoenix    AZ  111000.0  111700.0  112800.0  113700.0
# ...                    ...   ...       ...       ...       ...       ...
# 10725  Town of Wrightstown    WI  101100.0  101500.0  102700.0  103700.0
# 10726               Urbana    NY   77600.0   79400.0   80600.0   80200.0
# 10727          New Denmark    WI  113900.0  114000.0  115800.0  117600.0
# 10728               Angels    CA  148000.0  151200.0  153800.0  155600.0
# 10729              Holland    WI  150800.0  151000.0  151300.0  151000.0
#
#         2000-05   2000-06   2000-07   2000-08  ...  2015-11  2015-12  2016-01  \
# ...

# %%
df2 = pd.DataFrame(df[['State','RegionName']])

# %%
for year in range(2000,2016):
    #df2[str(year) + 'q1'] = df[[str(year) + '-01',str(year) + '-02',str(year) + '-03']]
    df2[str(year) + 'q1'] = df[[str(year) + '-01', str(year) + '-02', str(year) + '-03']].mean(axis = 1)
    df2[str(year) + 'q2'] = df[[str(year) + '-04', str(year) + '-05', str(year) + '-06']].mean(axis = 1)
    df2[str(year) + 'q3'] = df[[str(year) + '-07', str(year) + '-08', str(year) + '-09']].mean(axis = 1)
    df2[str(year) + 'q4'] = df[[str(year) + '-10', str(year) + '-11', str(year) + '-12']].mean(axis = 1)
    year = 2016
    df2[str(year) + 'q1'] = df[[str(year) + '-01', str(year) + '-02', str(year) + '-03']].mean(axis = 1)
    df2[str(year) + 'q2'] = df[[str(year) + '-04', str(year) + '-05', str(year) + '-06']].mean(axis = 1)
    df2[str(year) + 'q3'] = df[[str(year) + '-07', str(year) + '-08']].mean(axis = 1)
#df2['State'] = [states[state] for state in df2['State']]
df2 = df2.set_index(['State', 'RegionName'])
#ans = pd.DataFrame(df2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-198-e4a1862ac472> in <module>
#      10     df2[str(year) + 'q3'] = df[[str(year) + '-07', str(year) + '-08']].mean(axis = 1)
#      11 #df2['State'] = [states[state] for state in df2['State']]
# ---> 12 df2 = df2.set_index(['State', 'RegionName'])
#      13 #ans = pd.DataFrame(df2)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['State', 'RegionName'] are in the columns"

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
ans
# Out:
# '2009q4'

# %%
df2
# Out:
#                                   2000q1         2000q2         2000q3  \
# State RegionName
# NY    New York                       NaN            NaN            NaN
# CA    Los Angeles          207066.666667  214466.666667  220966.666667
# IL    Chicago              138400.000000  143633.333333  147866.666667
# PA    Philadelphia          53000.000000   53633.333333   54133.333333
# AZ    Phoenix              111833.333333  114366.666667  116000.000000
# ...                                  ...            ...            ...
# WI    Town of Wrightstown  101766.666667  105400.000000  111366.666667
# NY    Urbana                79200.000000   81666.666667   91700.000000
# WI    New Denmark          114566.666667  119266.666667  126066.666667
# CA    Angels               151000.000000  155900.000000  158100.000000
# WI    Holland              151033.333333  150500.000000  153233.333333
#
#                                   2000q4         2016q1         2016q2  \
# State RegionName
# ...

# %%
df2
# Out:
#       State           RegionName         2000q1         2000q2         2000q3  \
# 0        NY             New York            NaN            NaN            NaN
# 1        CA          Los Angeles  207066.666667  214466.666667  220966.666667
# 2        IL              Chicago  138400.000000  143633.333333  147866.666667
# 3        PA         Philadelphia   53000.000000   53633.333333   54133.333333
# 4        AZ              Phoenix  111833.333333  114366.666667  116000.000000
# ...     ...                  ...            ...            ...            ...
# 10725    WI  Town of Wrightstown  101766.666667  105400.000000  111366.666667
# 10726    NY               Urbana   79200.000000   81666.666667   91700.000000
# 10727    WI          New Denmark  114566.666667  119266.666667  126066.666667
# 10728    CA               Angels  151000.000000  155900.000000  158100.000000
# 10729    WI              Holland  151033.333333  150500.000000  153233.333333
#
# ...

# %%
chance

# %%
   df = pd.read_csv('City_Zhvi_AllHomes.csv')
    df = df.drop(df.columns[[0] + list(range(3,51))], axis=1)
#     df2 = df.set_index(['State', 'RegionName'])
    df2 = pd.DataFrame(df[['State', 'RegionName']])
#     print(df2)
    for year in range(2000, 2016):
        df2[str(year) + 'q1'] = df[[str(year) + '-01', str(year) + '-02', str(year) + '-03']].mean(axis = 1)
        df2[str(year) + 'q2'] = df[[str(year) + '-04', str(year) + '-05', str(year) + '-06']].mean(axis = 1)
        df2[str(year) + 'q3'] = df[[str(year) + '-07', str(year) + '-08', str(year) + '-09']].mean(axis = 1)
        df2[str(year) + 'q4'] = df[[str(year) + '-10', str(year) + '-11', str(year) + '-12']].mean(axis = 1)
    year = 2016
    df2[str(year) + 'q1'] = df[[str(year) + '-01', str(year) + '-02', str(year) + '-03']].mean(axis = 1)
    df2[str(year) + 'q2'] = df[[str(year) + '-04', str(year) + '-05', str(year) + '-06']].mean(axis = 1)
    df2[str(year) + 'q3'] = df[[str(year) + '-07', str(year) + '-08']].mean(axis = 1)
